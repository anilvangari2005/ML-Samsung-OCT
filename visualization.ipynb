# %%
import tensorflow as tf
import keras
import argparse
import keras.backend as K
from keras.models import load_model
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.chdir('/home/ubuntu/capstone/ML-Samsung-OCT')  # must change this in deployment
# !pwd
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/capstone/ML-Samsung-OCT

# %%
from vizgradcam.gradcam import VizGradCAM, create_grad_cam_viz, plot_viz, grad_image_preprocessing

# %%
# load trained model
weights = '/home/ubuntu/capstone/OpticNet-71/kermany2018.hdf5'  # double-check path when deploying, large model not in git repo
K.clear_session()
model = load_model(weights)
# Out:
# [2022-02-19 15:38:58.486 ip-172-31-81-72:7617 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-02-19 15:38:58.508 ip-172-31-81-72:7617 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.

# %%
# Samples from each class
data_root = '/home/ubuntu/capstone/ML-Samsung-OCT/data/test'  # must change this in deployment
sample_images = [
    data_root + '/CNV/CNV-1569-1.jpeg', # CNV
    data_root + '/DME/DME-1569-1.jpeg', # DME
    data_root + '/DRUSEN/DRUSEN-2967-1.jpeg', # DRUSEN
    data_root + '/NORMAL/NORMAL-1569-1.jpeg', # NORMAL
]

# %%
# CNV
input_img, overlay, heatmap = create_grad_cam_viz(model, sample_images[0])
plot_viz(input_img, overlay)

# %%
# DME
input_img, overlay, heatmap = create_grad_cam_viz(model, sample_images[1])
plot_viz(input_img, overlay)

# %%
# DRUSEN
input_img, overlay, heatmap = create_grad_cam_viz(model, sample_images[2])
plot_viz(input_img, overlay)

# %%
# NORMAL
input_img, overlay, heatmap = create_grad_cam_viz(model, sample_images[3])
plot_viz(input_img, overlay)
